# %% [markdown]
# ANS1==><!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <link rel="stylesheet" href="module11.css">
# </head>
# <body>
#     <h2>HTML SELECTOR</h2>
#     <p>Selectors are used to find tech html elements you want to design.</p>
#     <P> There are several different types of selectors in css.</P>
#
#     <ul>
#         <li><a href="#">simple selectors</a></li>
#         <li><a href="#"> combinator selectors</a></li>
#         <li><a href="#">pseudo -class selectors</a></li>
#         <li><a href="#">pseudo-elements selector</a></li>
#         <li><a href="#">Attribute selectors</a></li>
#     </ul>
#
#     <div>
#         <a href="https://www.google.com" target="_blank">Google</a>|
#         <a href="https://www.w3schools.com" target="_self">W3schools</a>|
#         <a href="https://aktu.ac.in" class="active">AKTU</a>
#     </div>
#     <div class="container">
#         <h2>Types of selctors</h2>
#     <p>css selectors rer used to find the HTML elements you wat to style.</p>
#     <P>We ca divide CSS selctors into five categories.</P>
#     </div>
# </body>
# </html>
# <!--BELOW IS THE CSS CODE-->
# html{
#     font-family: 'Courier New', Courier, monospace;
# }
# li a{
#     color:red;
# }
# h2:first-of-type{
#     color:white;
#     background-color: black;
# }
# p:first-of-type{
#     color:red;
# }
# a[href]{
#     color:red;
#     text-decoration: none;
# }
# a[class="active"]{
# color:green;
# font-weight: bold;
# text-decoration: underline;
# }
# a[target="_self"]{
#     background-color: yellow;
# }
# p:last-of-type::after{
#     content:".";
# }
# u1{
#     list-style:disc;
# }
# u1 li::marker{
#     color:blue;
# }
# p:nth-of-type::first-letter{
#     color:red;
#     font-size:30px;
# }

# %% [markdown]
# ANS2==>
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <link rel="stylesheet" href="module11.css">
# </head>
# <body>
#     <nav>
#         <ul>
#             <li><a href="#">Home</a></li>
#             <li><a href="#">About</a></li>
#             <li><a href="#">Service</a></li>
#             <li><a href="#">Portfolio</a></li>
#             <li><a href="#">Contact</a></li>
#         </ul>
#     </nav>
#     <div>
#         <p> Other content here....</p>
#     </div>
# </body>
# </html>
# <!--below is the css code-->
# nav ul li a{
#     text-decoration: none;
#     list-style-type:none;
# }
# av ul{
#     list-style-type: none;
#     padding:0;
#     margin:0;
# }
# nav>ul>li{
#     display: inline;
#     margin-right:10px;
# }
# nav ul li+li{
#     margin-left: 15px;
# }

# %% [markdown]
# ANS 3==><BR>
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <link rel="stylesheet" href="module11.css">
# </head>
# <body>
#     <h1> -- element -- </h1>
# </body>
# </html>
# <!--below is the css code--><br>
# h1::before{
#     content: "pseudo-element-selector";
#     color:blue;
# }
# h1::after{
#     content: "pseudo-element-selector";
#     color:green;
# }

# %% [markdown]
# ANS 4==><br>
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <link rel="stylesheet" href="module11.css">
# </head>
# <body>
#     <button class="pw-button">PW SKILLS</button>
# </body>
# </html>
# /*below is the css code*/
# .pw-button{
#     position: relative;
#     padding: 12px 24px;
#     background-color: #2563eb;
#     color: white;
#     font-size: 18px;
#     border:none;
#     border-radius: 10px;
#     transform: all 0.3s ease;
# }
# .pw-button::before{
#     content: ">> ";
#     color: white;
# }
# .pw-button::after{
#     content: " <<";
#     color:white;
# }
# .pw-button:hover{
#     background-color: #1d4ed8;
#     box-shadow: 0 8px 16px rgba(0,0,0,0.3);
#     cursor: pointer;
# }
